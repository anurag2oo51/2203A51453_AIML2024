# %% [markdown]
# Part-02 : Lab Task is to visualize the datasets or data using Matplotlib function graphs

# %%
people = ['Aravind','Charan','Shivan','Akash','Pavan','Sunny']
age=[19,18,21,14,12,19]
weight=[78,60,41,40,51,80]
height=[179,190,160,173,169,152]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight, height)
plt.title("relationship between weight and height of patients")
plt.ylabel("Height in Meters")
plt.xlabel("weight of  patients in kgs")
plt.show()

# %% [markdown]
# Generate Barr graph

# %%
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')

plt.bar(x=people,height=weight, width=0.6,color ="orange",edgecolor='k',alpha=0.6)

plt.xlabel("people",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# Generate Histogram

# %%
import numpy as np
plt.figure(figsize=(7,5))

plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bins=5)

plt.title("Histogram of partient weight", fontsize=18)
plt.xlabel("weight (in kgs)",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# part 3 : Access data from various data source using built in function

# %% [markdown]
# ---

# %%
import pandas as pd
file=pd.read_excel("/content/Book.xlsx")
file
# Out:
#    Sn       Name Gender nationality organization  work experience
# 0   1    Michael      M    american       google               14
# 1   2    shambhu      M       asian        adobe               12
# 2   3     mustak      M    pakistan    microsoft               16
# 3   4  song kang      M      korean       amazon               13

# %%
import pandas as pd
file1=pd.read_table("/content/Booktxt.txt")
file1
# Out:
#    Sn       Name Gender nationality organization  work experience  Unnamed: 6
# 0   1    Michael      M    american       google               14         NaN
# 1   2    shambhu      M       asian        adobe               12         NaN
# 2   3     mustak      M    pakistan    microsoft               16         NaN
# 3   4  song kang      M      korean       amazon               13         NaN

# %%
import pandas as pd
file3=pd.read_csv("/content/Bookcsv.csv")
file3
# Out:
#    Sn       Name Gender nationality organization  work experience  Unnamed: 6
# 0   1    Michael      M    american       google               14         NaN
# 1   2    shambhu      M       asian        adobe               12         NaN
# 2   3     mustak      M    pakistan    microsoft               16         NaN
# 3   4  song kang      M      korean       amazon               13         NaN
